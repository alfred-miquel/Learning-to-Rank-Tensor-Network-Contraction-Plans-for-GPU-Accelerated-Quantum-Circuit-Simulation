# %% [markdown]
# # Getting Features

# %% [markdown]
# This notebook demonstrates the creation of quantum circuits and their contraction plans. Once you acquire a plan, certain features will be figured out.
# ---

# %% [markdown]
# ## Step 0: Loading software

# %% [markdown]
#  First of all, we create a new project to load all the neccesary software

# %%
] activate New_Project_on_QXTools;
# Out:
#   Activating new project at `C:\Users\alfre\Desktop\Julia\Setembre_2026\Github\18_features_notebook_1\New_Project_on_QXTools`

# %%
# The execution of this cell is only necessary the first time you activate the same project.

import Pkg; 
Pkg.add("QXTools")
Pkg.add("QXGraphDecompositions")
Pkg.add("QXZoo")
Pkg.add("DataStructures")
Pkg.add("QXTns")
Pkg.add("NDTensors")
Pkg.add("ITensors")
Pkg.add("LightGraphs")
Pkg.add("PyCall")
# Out:
#    Resolving package versions...
#     Updating `C:\Users\Usuario\.julia\environments\v1.9\Project.toml`
#   [84f0eee1] + QXTools v1.0.0
#     Updating `C:\Users\Usuario\.julia\environments\v1.9\Manifest.toml`
#   [84f0eee1] + QXTools v1.0.0
# ⌅ [6aa20fa7] + TensorOperations v3.2.5
#         Info Packages marked with ⌅ have new versions available but compatibility constraints restrict them from upgrading. To see why use `status --outdated -m`
# Precompiling project...
#   ✓ GeometryBasics
#   ✓ QXTools
#   ✓ NetworkLayout
#   ✓ GraphRecipes
#   4 dependencies successfully precompiled in 46 seconds. 263 already precompiled. 1 skipped during auto due to previous errors.
#    Resolving package versions...
#   No Changes to `C:\Users\Usuario\.julia\environments\v1.9\Project.toml`
#   No Changes to `C:\Users\Usuario\.julia\environments\v1.9\Manifest.toml`
#    Resolving package versions...
#   No Changes to `C:\Users\Usuario\.julia\environments\v1.9\Project.toml`
# ...

# %%
begin
 using QXTools
 using QXTns
 using QXZoo
 using PyCall
 using QXGraphDecompositions
 using LightGraphs
 using DataStructures
 using TimerOutputs
 using ITensors
 using LinearAlgebra
 using NDTensors
 using CUDA
end
# Out:
# WARNING: method definition for asarray at C:\Users\Usuario\.julia\packages\OMEinsum\0C2IK\src\cueinsum.jl:8 declares type variable T but does not use it.
# WARNING: method definition for expanddims! at C:\Users\Usuario\.julia\packages\OMEinsum\0C2IK\src\cueinsum.jl:67 declares type variable LT but does not use it.
# [ Info: OMEinsum loaded the CUDA module successfully

# %%
# Load custom functions
begin
 include("../src/funcions_article_IA.jl");
 include("../src/funcions_qasm.jl");
end

# %% [markdown]
# ## Step 1: Create a QASM Circuit
# We begin by creating a QASM circuit from a file or directly from a text.

# %%
# alternative 1 : as a text file, the QASM file allows for direct writing with the necessary syntax
begin
    
qasm_string = """
// Benchmark was created by MQT Bench on 2024-03-17
// For more information about MQT Bench, please visit https://www.cda.cit.tum.de/mqtbench/
// MQT Bench version: 1.1.0
// Qiskit version: 1.0.2

OPENQASM 2.0;
include "qelib1.inc";
qreg q[40];
creg c[39];
u2(0,0) q[0];
u2(0,0) q[1];
h q[2];
u2(0,0) q[3];
h q[4];
u2(0,0) q[5];
u2(0,0) q[6];
h q[7];
u2(0,0) q[8];
u2(0,0) q[9];
h q[10];
u2(0,0) q[11];
u2(0,0) q[12];
h q[13];
h q[14];
u2(0,0) q[15];
h q[16];
h q[17];
h q[18];
h q[19];
h q[20];
u2(0,0) q[21];
h q[22];
h q[23];
u2(0,0) q[24];
u2(0,0) q[25];
h q[26];
h q[27];
u2(0,0) q[28];
h q[29];
h q[30];
u2(0,0) q[31];
h q[32];
h q[33];
h q[34];
u2(0,0) q[35];
u2(0,0) q[36];
h q[37];
u2(0,0) q[38];
u2(-pi,-pi) q[39];
cx q[0],q[39];
u2(-pi,-pi) q[0];
cx q[1],q[39];
u2(-pi,-pi) q[1];
cx q[2],q[39];
h q[2];
cx q[3],q[39];
u2(-pi,-pi) q[3];
cx q[4],q[39];
h q[4];
cx q[5],q[39];
u2(-pi,-pi) q[5];
cx q[6],q[39];
u2(-pi,-pi) q[6];
cx q[7],q[39];
h q[7];
cx q[8],q[39];
u2(-pi,-pi) q[8];
cx q[9],q[39];
u2(-pi,-pi) q[9];
cx q[10],q[39];
h q[10];
cx q[11],q[39];
u2(-pi,-pi) q[11];
cx q[12],q[39];
u2(-pi,-pi) q[12];
cx q[13],q[39];
h q[13];
cx q[14],q[39];
h q[14];
cx q[15],q[39];
u2(-pi,-pi) q[15];
cx q[16],q[39];
h q[16];
cx q[17],q[39];
h q[17];
cx q[18],q[39];
h q[18];
cx q[19],q[39];
h q[19];
cx q[20],q[39];
h q[20];
cx q[21],q[39];
u2(-pi,-pi) q[21];
cx q[22],q[39];
h q[22];
cx q[23],q[39];
h q[23];
cx q[24],q[39];
u2(-pi,-pi) q[24];
cx q[25],q[39];
u2(-pi,-pi) q[25];
cx q[26],q[39];
h q[26];
cx q[27],q[39];
h q[27];
cx q[28],q[39];
u2(-pi,-pi) q[28];
cx q[29],q[39];
h q[29];
cx q[30],q[39];
h q[30];
cx q[31],q[39];
u2(-pi,-pi) q[31];
cx q[32],q[39];
h q[32];
cx q[33],q[39];
h q[33];
cx q[34],q[39];
h q[34];
cx q[35],q[39];
u2(-pi,-pi) q[35];
cx q[36],q[39];
u2(-pi,-pi) q[36];
cx q[37],q[39];
h q[37];
cx q[38],q[39];
u2(-pi,-pi) q[38];
barrier q[0],q[1],q[2],q[3],q[4],q[5],q[6],q[7],q[8],q[9],q[10],q[11],q[12],q[13],q[14],q[15],q[16],q[17],q[18],q[19],q[20],q[21],q[22],q[23],q[24],q[25],q[26],q[27],q[28],q[29],q[30],q[31],q[32],q[33],q[34],q[35],q[36],q[37],q[38],q[39];
measure q[0] -> c[0];
measure q[1] -> c[1];
measure q[2] -> c[2];
measure q[3] -> c[3];
measure q[4] -> c[4];
measure q[5] -> c[5];
measure q[6] -> c[6];
measure q[7] -> c[7];
measure q[8] -> c[8];
measure q[9] -> c[9];
measure q[10] -> c[10];
measure q[11] -> c[11];
measure q[12] -> c[12];
measure q[13] -> c[13];
measure q[14] -> c[14];
measure q[15] -> c[15];
measure q[16] -> c[16];
measure q[17] -> c[17];
measure q[18] -> c[18];
measure q[19] -> c[19];
measure q[20] -> c[20];
measure q[21] -> c[21];
measure q[22] -> c[22];
measure q[23] -> c[23];
measure q[24] -> c[24];
measure q[25] -> c[25];
measure q[26] -> c[26];
measure q[27] -> c[27];
measure q[28] -> c[28];
measure q[29] -> c[29];
measure q[30] -> c[30];
measure q[31] -> c[31];
measure q[32] -> c[32];
measure q[33] -> c[33];
measure q[34] -> c[34];
measure q[35] -> c[35];
measure q[36] -> c[36];
measure q[37] -> c[37];
measure q[38] -> c[38];
"""

open("dj_indep_qiskit_40.qasm", "w") do io
    write(io, qasm_string)
end


qasm_file = "dj_indep_qiskit_40.qasm"
circ= import_from_qasm(qasm_file)    
tnc = convert_to_tnc(circ)  # Convert the qasm circuit into a tensor network circuit   

println("File qasm generated and converted into a tensor network circuit")    
end

# %%
# second alternative: load from a file
begin
       qasm_file = "../Data/circuits/dj_indep_qiskit_40.qasm"
       circ= import_from_qasm(qasm_file)    
       tnc = convert_to_tnc(circ)  # Convert the qasm circuit into a tensor network circuit
       println("File qasm generated and converted into a tensor network circuit")
end

# %% [markdown]
# ---
#
# ## Step 2: Contraction plans
# We perform contraction plans of the tensor network using the Flow cutter algorithm. We can use Girvan–Newman algorithm and others to get a contraction order.

# %%
# Find a good contraction plan
plan = flow_cutter_contraction_plan(tnc; time=10)

# %% [raw]
# 236-element Vector{Tuple{Symbol, Symbol, Symbol}}:
#  (:t157, :t236, :I1)
#  (:t3, :t160, :I2)
#  (:t154, :t235, :I3)
#  (:t11, :t168, :I4)
#  (:t49, :t200, :I5)
#  (:t52, :t201, :I6)
#  (:t148, :t233, :I7)
#  (:t55, :t202, :I8)
#  (:t58, :t203, :I9)
#  (:t12, :t169, :I10)
#  (:t142, :t231, :I11)
#  (:t61, :t204, :I12)
#  (:t64, :t205, :I13)
#  (:t67, :t206, :I14)
#  (:t136, :t229, :I15)
#  (:t70, :t207, :I16)
#  (:t133, :t228, :I17)
#  (:t13, :t170, :I18)
#  ⋮
#  (:I36, :I30, :I65)
#  (:I65, :I9, :I66)
#  (:I15, :I66, :I67)
#  (:I8, :I67, :I68)
#  (:I64, :I1, :I69)
#  (:I27, :I69, :I70)
#  (:I68, :I40, :I71)
#  (:I23, :I70, :I72)
#  (:I24, :I72, :I73)
#  (:I73, :I10, :I74)
#  (:I19, :I74, :I75)
#  (:I26, :I75, :I76)
#  (:I41, :I76, :I77)
#  (:I71, :I33, :I78)
#  (:I77, :I78, :I79)
#  (:t1, :t158, :I157)
#  (:I157, :I79, :I158)

# %% [markdown]
# ---
# ## Step 3: Getting contraction features in a file
# We perform  a fake contraction in the GPU to get some tensor features.

# %%
using CUDA
begin
        for i in keys(tnc.tn.:tensor_map)
                             tnc.tn.:tensor_map[i].storage= CuArray(tnc.tn.:tensor_map[i].storage)
                         end

        Dades= contract_tn_rank_mock!(tnc.tn, plan,mock= true,verbose=true);

 end

# %% [markdown]
# A file named ``fitxer_sortida.txt`` is generated .

# %% [raw]
# readdir() # we can use this command in Julia for showing files in a directory

# %%
readlines("fitxer_sortida.txt")

# %% [raw]
# 236-element Vector{String}:
#  "t157 t236 I1 2 1 1  Index{Int64}[(dim=2|id=523|\"Qubit39\")'''] 0.87146931"
#  "t3 t160 I2 2 1 1  Index{Int64}[(dim=2|id=151|\"Qubit3\")] 0.011824654"
#  "t154 t235 I3 2 1 1  Index{Int64}[(dim=2|id=469|\"Qubit38\")'''] 0.000374077"
#  "t11 t168 I4 2 1 1  Index{Int64}[(dim=2|id=686|\"Qubit11\")] 0.000305059"
#  "t49 t200 I5 2 1 1  Index{Int64}[(dim=2|id=151|\"Qubit3\")'''] 0.000297304"
#  "t52 t201 I6 2 1 1  Index{Int64}[(dim=2|id=276|\"Qubit4\")'''] 0.000297373"
#  "t148 t233 I7 2 1 1  Index{Int64}[(dim=2|id=603|\"Qubit36\")'''] 0.000290789"
#  "t55 t202 I8 2 1 1  Index{Int64}[(dim=2|id=461|\"Qubit5\")'''] 0.000292259"
#  "t58 t203 I9 2 1 1  Index{Int64}[(dim=2|id=336|\"Qubit6\")'''] 0.000289553"
#  "t12 t169 I10 2 1 1  Index{Int64}[(dim=2|id=609|\"Qubit12\")] 0.000285008"
#  "t142 t231 I11 2 1 1  Index{Int64}[(dim=2|id=200|\"Qubit34\")'''] 0.000322694"
#  "t61 t204 I12 2 1 1  Index{Int64}[(dim=2|id=315|\"Qubit7\")'''] 0.000301863"
#  "t64 t205 I13 2 1 1  Index{Int64}[(dim=2|id=509|\"Qubit8\")'''] 0.000296103"
#  "t67 t206 I14 2 1 1  Index{Int64}[(dim=2|id=983|\"Qubit9\")'''] 0.000303896"
#  "t136 t229 I15 2 1 1  Index{Int64}[(dim=2|id=807|\"Qubit32\")'''] 0.000287697"
#  "t70 t207 I16 2 1 1  Index{Int64}[(dim=2|id=712|\"Qubit10\")'''] 0.000287322"
#  "t133 t228 I17 2 1 1  Index{Int64}[(dim=2|id=814|\"Qubit31\")'''] 0.000287008"
#  "t13 t170 I18 2 1 1  Index{Int64}[(dim=2|id=178|\"Qubit13\")] 0.000279907"
#  ⋮
#  "I36 I30 I65 2 2 2  Index[(dim=2|id=102|\"Qubit40\")''] 0.000475429"
#  "I65 I9 I66 2 2 2  Index[(dim=2|id=102|\"Qubit40\")'''] 0.000410777"
#  "I15 I66 I67 2 2 2  Index[(dim=2|id=102|\"Qubit40\")'4] 0.00037762"
#  "I8 I67 I68 2 2 2  Index[(dim=2|id=102|\"Qubit40\")'5] 0.000353394"
#  "I64 I1 I69 1 2 1  Index[(dim=2|id=102|\"Qubit40\")'16] 0.000320585"
#  "I27 I69 I70 2 1 1  Index[(dim=2|id=102|\"Qubit40\")'15] 0.000278127"
#  "I68 I40 I71 2 2 2  Index[(dim=2|id=102|\"Qubit40\")'6] 0.000283724"
#  "I23 I70 I72 2 1 1  Index[(dim=2|id=102|\"Qubit40\")'14] 0.000230775"
#  "I24 I72 I73 2 1 1  Index[(dim=2|id=102|\"Qubit40\")'13] 0.000206726"
#  "I73 I10 I74 1 2 1  Index[(dim=2|id=102|\"Qubit40\")'12] 0.000186442"
#  "I19 I74 I75 2 1 1  Index[(dim=2|id=102|\"Qubit40\")'11] 0.000168473"
#  "I26 I75 I76 2 1 1  Index[(dim=2|id=102|\"Qubit40\")'10] 0.00014119"
#  "I41 I76 I77 2 1 1  Index[(dim=2|id=102|\"Qubit40\")'9] 0.000123721"
#  "I71 I33 I78 2 2 2  Index[(dim=2|id=102|\"Qubit40\")'7] 0.000121317"
#  "I77 I78 I79 1 2 1  Index[(dim=2|id=102|\"Qubit40\")'8] 9.656e-5"
#  "t1 t158 I157 2 1 1  Index{Int64}[(dim=2|id=159|\"Qubit1\")] 0.000534017"
#  "I157 I79 I158 1 1 0  Index[(dim=2|id=159|\"Qubit1\")'] 0.073561786"

# %% [markdown]
# ### Brief explanation
#
# - **t1, t2, t3**: names of the tensors (first three words)
#   These are the identifiers of the two input tensors being contracted and the resulting output tensor. For example, in a line like `t518 t564 I1 ...`, `t518` and `t564` are the two tensors being contracted, and `I1` is the tensor that results from the contraction.
#
# - **r1, r2, r3**: ranks (or orders) of the tensors (words 4, 5, 6)
#   These are integer values indicating the number of indices (dimensions) of each tensor. For example, a rank of `2` means the tensor has 2 indices, a rank of `1` means it is a vector-like tensor, and so on. The three values correspond respectively to the ranks of `t1`, `t2`, and `t3`.
#
# - **indices**: common contraction indices (word 7)
#   This field describes the shared indices between the two tensors being contracted. It specifies which index labels (e.g., `id=186`, `"Qubit16"`, with possible prime markers like `'19`) are summed over during the contraction. In tensor network language, these are the "bond" indices that connect the two tensors.
#
# - **cost**: contraction time (last word)
#   This is a floating-point number representing the computational cost or execution time associated with performing this particular contraction step. It is typically used to evaluate or compare the efficiency of a contraction plan.
#
#
#   *Note*: In this example, we do not contract "really" in a GPU, so the time results are negligible

# %% [markdown]
# ---
#
# ### Summary
# This notebook demonstrated:
# 1. The creation of tensor network from a qasm file .
# 2. Contraction plan using the FlowCutter algorithm.
# 3. Convert this plan into a file with some tensor characteristics to get future features
#
#
# Thank you for exploring tensor network construction with us!
