# %% [markdown]
# ## Getting 18 features from a file

# %% [markdown]
# In this notebook we will generate vectors with the 18 original features or characteristics cited in the article.
#
# As a starting point, there will be the files named *"file_sortida.txt"* obtained in previous notebooks or seven testing files from the original dataset : *"resultats_QFT_5_pla_fc.txt", "resultats_QFT_5_pla_gn.txt", "resultats_QFT_5_pla_jdrasil.txt", "resultats_QFT_5_pla_mf.txt", "resultats_QFT_5_pla_minfill_mrs.txt", "resultats_QFT_5_pla_minfillbg_mrs.txt", "resultats_QFT_5_pla_tamaki.txt"* .
#
# These vectors will make up the general dataset of the article with all the circuits and their characteristics.

# %%
]activate New_project
# Out:
#   Activating new project at `C:\Users\alfre\Desktop\Julia\Setembre_2026\Github\Notebooks\Nou_projecte`

# %%
import Pkg; Pkg.add("DataFrames")
# Out:
#     Updating registry at `C:\Users\alfre\.julia\registries\General.toml`
#    Resolving package versions...
#    Installed StringManipulation ─ v0.5.0
#    Installed LaTeXStrings ─────── v1.4.1
#    Installed InlineStrings ────── v1.4.6
#    Installed Statistics ───────── v1.11.5
#    Installed Preferences ──────── v1.6.0
#    Installed PrettyTables ─────── v3.4.8
#     Updating `C:\Users\alfre\Desktop\Julia\Setembre_2026\Github\Notebooks\Nou_projecte\Project.toml`
#   [a93c6f00] + DataFrames v1.8.2 [loaded: v1.8.1]
#     Updating `C:\Users\alfre\Desktop\Julia\Setembre_2026\Github\Notebooks\Nou_projecte\Manifest.toml`
#   [34da2185] + Compat v4.18.1
#   [a8cc5b0e] + Crayons v4.2.0 [loaded: v4.1.1]
#   [9a962f9c] + DataAPI v1.16.0
#   [a93c6f00] + DataFrames v1.8.2 [loaded: v1.8.1]
#   [864edb3b] + DataStructures v0.19.6 [loaded: v0.19.4]
#   [e2d170a0] + DataValueInterfaces v1.0.0
# ⌅ [842dd82b] + InlineStrings v1.4.6 [loaded: v1.4.5]
#   [41ab1584] + InvertedIndices v1.3.1
# ...

# %%
include("../src/Funcions_de_Features_v_5.jl");# if you are using Windows, you should exchange "/" by "\\"
include("../src/Analisi_estadistic_circuits.jl")
# Out:
# mostrar_estadistics (generic function with 1 method)

# %% [markdown]
# ### Generation of two vectors: ``nom_v`` with names of circuits and ``features_v`` with 18 features

# %%
# features from the article

feature_names = [
        "max_cost",              # 1. max cost
        "log2_sum_flops_val",    # 2. log2 sum flops
        "topq_mean",             # 3. topq mean cost
        "avg_cost",              # 4. avg cost
        "std_cost",              # 5. std cost
        "n_steps",               # 6. n steps
        "frac_tiny",             # 7. frac tiny steps
        "max_out_rank",          # 8. max out rank
        "avg_out_rank",          # 9. avg out rank
        "costw_out_rank",        # 10. costw out rank
        "p_at_max_cost_val",     # 11. p at max cost
        "max_red_rank_val",      # 12. max red rank
        "costw_red_rank_val",    # 13. costw red rank
        "k_at_max_cost_val",     # 14. k at max cost
        "max_asym_val",          # 15. max asym 
        "avg_asym",              # 16. avg asym
        "costw_asym_val",        # 17. costw asym 
        "d_at_max_cost_val"      # 18. d at max cost
    ]
# Out:
# 18-element Vector{String}:
#  "max_cost"
#  "log2_sum_flops_val"
#  "topq_mean"
#  "avg_cost"
#  "std_cost"
#  "n_steps"
#  "frac_tiny"
#  "max_out_rank"
#  "avg_out_rank"
#  "costw_out_rank"
#  "p_at_max_cost_val"
#  "max_red_rank_val"
#  "costw_red_rank_val"
#  "k_at_max_cost_val"
#  "max_asym_val"
#  "avg_asym"
#  "costw_asym_val"
#  "d_at_max_cost_val"

# %%
features_simbols = Symbol.(feature_names)
# Out:
# 18-element Vector{Symbol}:
#  :max_cost
#  :log2_sum_flops_val
#  :topq_mean
#  :avg_cost
#  :std_cost
#  :n_steps
#  :frac_tiny
#  :max_out_rank
#  :avg_out_rank
#  :costw_out_rank
#  :p_at_max_cost_val
#  :max_red_rank_val
#  :costw_red_rank_val
#  :k_at_max_cost_val
#  :max_asym_val
#  :avg_asym
#  :costw_asym_val
#  :d_at_max_cost_val

# %%
### Getting names and features in two vectors
begin
     

    directori = "../Data/plans"
    
    nom_v = []

    features_v=[]


    circuit_v = ["resultats_QFT_5_pla_fc.txt","resultats_QFT_5_pla_gn.txt","resultats_QFT_5_pla_jdrasil.txt","resultats_QFT_5_pla_mf.txt","resultats_QFT_5_pla_minfill_mrs.txt","resultats_QFT_5_pla_minfillbg_mrs.txt","resultats_QFT_5_pla_tamaki.txt"]        
  
    for circuit in circuit_v
    
          try
            filename= directori* "/" * circuit # if you are using Windows, you should exchange "/" by "\\"
            nom= extraure_nom_circuit(circuit)
            contractions= get_contractions(filename)
            features= get_features_v5(contractions)
            push!(nom_v,nom)
            push!(features_v, features)

           catch
               println("Error in $circuit")
           end
        
      
    
        end

end

# %%
println(" The name of the circuits: ", nom_v)

# %% [raw]
#  The name of the circuits: Any["QFT_5_pla_fc", "QFT_5_pla_gn", "QFT_5_pla_jdrasil", "QFT_5_pla_mf", "QFT_5_pla_minfill_mrs", "QFT_5_pla_minfillbg_mrs", "QFT_5_pla_tamaki"]

# %%
println(" Features vector: ",features_v)

# %% [raw]
# Features vector: Any[[8.0, 10.850186837645774, 8.0, 4.309523809523809, 1.6599749518841225, 42.0, 0.047619047619047616, 6.0, 3.0714285714285716, 4.912242686890575, 6.0, 3.0, 1.7410617551462622, 2.0, 0.99999950000025, 0.3944442517329169, 0.2702780056530906, 0.24999995833334027], [8.0, 11.00842862207058, 8.0, 4.523809523809524, 1.6415057816305725, 42.0, 0.023809523809523808, 6.0, 3.2857142857142856, 5.034951456310679, 6.0, 4.0, 1.6757281553398058, 2.0, 0.9999997500000625, 0.4126982288360739, 0.29967630118664673, 0.33333327777778704], [8.0, 10.603626344986193, 8.0, 4.333333333333333, 1.4426714154678917, 42.0, 0.023809523809523808, 6.0, 3.0952380952380953, 4.5475578406169666, 6.0, 6.0, 1.6375321336760926, 2.0, 0.99999950000025, 0.3650791904762839, 0.20479856869468172, 0.33333327777778704], [8.0, 10.603626344986193, 8.0, 4.333333333333333, 1.4426714154678917, 42.0, 0.023809523809523808, 6.0, 3.0952380952380953, 4.5475578406169666, 6.0, 6.0, 1.6375321336760926, 2.0, 0.99999950000025, 0.3650791904762839, 0.20479856869468172, 0.33333327777778704], [8.0, 10.721099188707186, 8.0, 4.309523809523809, 1.5537224418307627, 42.0, 0.047619047619047616, 6.0, 3.0714285714285716, 4.637440758293839, 5.666666666666667, 3.0, 1.7890995260663507, 2.3333333333333335, 0.99999950000025, 0.38095220291014714, 0.21595570225384142, 0.17777774592593168], [8.0, 10.544964432789238, 8.0, 4.214285714285714, 1.5066634804114605, 42.0, 0.047619047619047616, 6.0, 2.9761904761904763, 4.527443105756359, 6.0, 3.0, 1.6586345381526104, 2.0, 0.99999950000025, 0.3769839375001121, 0.2597054112747596, 0.33333327777778704], [7.0, 10.236014191900084, 7.0, 4.166666666666667, 1.3778149308741858, 42.0, 0.023809523809523808, 5.0, 2.9285714285714284, 3.9635157545605306, 5.0, 2.0, 1.550580431177446, 2.0, 0.99999950000025, 0.38015853951069445, 0.2279711743799879, 0.199999960000008]]

# %% [markdown]
# ## Dictionary
#
# As an alternative, we collect all the information in a dictionary

# %%
begin
              # We create the dictionary and fill it
              circuit_dict = Dict{String, Dict{String, Float64}}()

                            
              for (i, circuit_id) in enumerate(nom_v)
                  if length(features_v[i]) != length(feature_names)
                      error("The features for the circuit $circuit_id are not correct")
                  end

                  # this is  an internal dictionary for every circuit
                  circuit_features = Dict{String, Float64}()

                  for (j, feature_name) in enumerate(feature_names)
                      circuit_features[feature_name] = features_v[i][j]
                  end

                  # join the circuit to the main dictionary
                  circuit_dict[circuit_id] = circuit_features
              end
end

# %%
println(" The dictionary with circuits and features is : ", circuit_dict)

# %% [raw]
# The dictionary with circuits and features is : Dict("QFT_5_pla_tamaki" => Dict("max_out_rank" => 5.0, "avg_cost" => 4.166666666666667, "max_red_rank_val" => 2.0, "topq_mean" => 7.0, "frac_tiny" => 0.023809523809523808, "avg_asym" => 0.38015853951069445, "max_cost" => 7.0, "log2_sum_flops_val" => 10.236014191900084, "std_cost" => 1.3778149308741858, "max_asym_val" => 0.99999950000025, "costw_out_rank" => 3.9635157545605306, "costw_asym_val" => 0.2279711743799879, "p_at_max_cost_val" => 5.0, "d_at_max_cost_val" => 0.199999960000008, "costw_red_rank_val" => 1.550580431177446, "avg_out_rank" => 2.9285714285714284, "k_at_max_cost_val" => 2.0, "n_steps" => 42.0), "QFT_5_pla_mf" => Dict("max_out_rank" => 6.0, "avg_cost" => 4.333333333333333, "max_red_rank_val" => 6.0, "topq_mean" => 8.0, "frac_tiny" => 0.023809523809523808, "avg_asym" => 0.3650791904762839, "max_cost" => 8.0, "log2_sum_flops_val" => 10.603626344986193, "std_cost" => 1.4426714154678917, "max_asym_val" => 0.99999950000025, "costw_out_rank" => 4.5475578406169666, "costw_asym_val" => 0.20479856869468172, "p_at_max_cost_val" => 6.0, "d_at_max_cost_val" => 0.33333327777778704, "costw_red_rank_val" => 1.6375321336760926, "avg_out_rank" => 3.0952380952380953, "k_at_max_cost_val" => 2.0, "n_steps" => 42.0), "QFT_5_pla_minfill_mrs" => Dict("max_out_rank" => 6.0, "avg_cost" => 4.309523809523809, "max_red_rank_val" => 3.0, "topq_mean" => 8.0, "frac_tiny" => 0.047619047619047616, "avg_asym" => 0.38095220291014714, "max_cost" => 8.0, "log2_sum_flops_val" => 10.721099188707186, "std_cost" => 1.5537224418307627, "max_asym_val" => 0.99999950000025, "costw_out_rank" => 4.637440758293839, "costw_asym_val" => 0.21595570225384142, "p_at_max_cost_val" => 5.666666666666667, "d_at_max_cost_val" => 0.17777774592593168, "costw_red_rank_val" => 1.7890995260663507, "avg_out_rank" => 3.0714285714285716, "k_at_max_cost_val" => 2.3333333333333335, "n_steps" => 42.0), "QFT_5_pla_jdrasil" => Dict("max_out_rank" => 6.0, "avg_cost" => 4.333333333333333, "max_red_rank_val" => 6.0, "topq_mean" => 8.0, "frac_tiny" => 0.023809523809523808, "avg_asym" => 0.3650791904762839, "max_cost" => 8.0, "log2_sum_flops_val" => 10.603626344986193, "std_cost" => 1.4426714154678917, "max_asym_val" => 0.99999950000025, "costw_out_rank" => 4.5475578406169666, "costw_asym_val" => 0.20479856869468172, "p_at_max_cost_val" => 6.0, "d_at_max_cost_val" => 0.33333327777778704, "costw_red_rank_val" => 1.6375321336760926, "avg_out_rank" => 3.0952380952380953, "k_at_max_cost_val" => 2.0, "n_steps" => 42.0), "QFT_5_pla_fc" => Dict("max_out_rank" => 6.0, "avg_cost" => 4.309523809523809, "max_red_rank_val" => 3.0, "topq_mean" => 8.0, "frac_tiny" => 0.047619047619047616, "avg_asym" => 0.3944442517329169, "max_cost" => 8.0, "log2_sum_flops_val" => 10.850186837645774, "std_cost" => 1.6599749518841225, "max_asym_val" => 0.99999950000025, "costw_out_rank" => 4.912242686890575, "costw_asym_val" => 0.2702780056530906, "p_at_max_cost_val" => 6.0, "d_at_max_cost_val" => 0.24999995833334027, "costw_red_rank_val" => 1.7410617551462622, "avg_out_rank" => 3.0714285714285716, "k_at_max_cost_val" => 2.0, "n_steps" => 42.0), "QFT_5_pla_minfillbg_mrs" => Dict("max_out_rank" => 6.0, "avg_cost" => 4.214285714285714, "max_red_rank_val" => 3.0, "topq_mean" => 8.0, "frac_tiny" => 0.047619047619047616, "avg_asym" => 0.3769839375001121, "max_cost" => 8.0, "log2_sum_flops_val" => 10.544964432789238, "std_cost" => 1.5066634804114605, "max_asym_val" => 0.99999950000025, "costw_out_rank" => 4.527443105756359, "costw_asym_val" => 0.2597054112747596, "p_at_max_cost_val" => 6.0, "d_at_max_cost_val" => 0.33333327777778704, "costw_red_rank_val" => 1.6586345381526104, "avg_out_rank" => 2.9761904761904763, "k_at_max_cost_val" => 2.0, "n_steps" => 42.0), "QFT_5_pla_gn" => Dict("max_out_rank" => 6.0, "avg_cost" => 4.523809523809524, "max_red_rank_val" => 4.0, "topq_mean" => 8.0, "frac_tiny" => 0.023809523809523808, "avg_asym" => 0.4126982288360739, "max_cost" => 8.0, "log2_sum_flops_val" => 11.00842862207058, "std_cost" => 1.6415057816305725, "max_asym_val" => 0.9999997500000625, "costw_out_rank" => 5.034951456310679, "costw_asym_val" => 0.29967630118664673, "p_at_max_cost_val" => 6.0, "d_at_max_cost_val" => 0.33333327777778704, "costw_red_rank_val" => 1.6757281553398058, "avg_out_rank" => 3.2857142857142856, "k_at_max_cost_val" => 2.0, "n_steps" => 42.0))

# %%
# if we want only the results of one circuit, for example.
 circuit_dict["QFT_5_pla_tamaki"]

# %% [raw]
# Dict{String, Float64} with 18 entries:
#   "max_out_rank"       => 5.0
#   "avg_cost"           => 4.16667
#   "max_red_rank_val"   => 2.0
#   "topq_mean"          => 7.0
#   "frac_tiny"          => 0.0238095
#   "avg_asym"           => 0.380159
#   "max_cost"           => 7.0
#   "log2_sum_flops_val" => 10.236
#   "std_cost"           => 1.37781
#   "max_asym_val"       => 1.0
#   "costw_out_rank"     => 3.96352
#   "costw_asym_val"     => 0.227971
#   "p_at_max_cost_val"  => 5.0
#   "d_at_max_cost_val"  => 0.2
#   "costw_red_rank_val" => 1.55058
#   "avg_out_rank"       => 2.92857
#   "k_at_max_cost_val"  => 2.0
#   "n_steps"            => 42.0

# %% [markdown]
# ### Dataframe
#
# We also collect the same information in a Dataframe

# %%
       using DataFrames

       
       function create_circuit_dataframe_direct(id_circuits, features_v, feature_names)
        
           # checking dimensions
           if length(id_circuits) != length(features_v)
               error("El nombre de circuits i features no coincideix")
           end

           # DataFrame
           df = DataFrame()
           df.circuit_name = id_circuits

           # filling it with features
           for (i, feature_name) in enumerate(feature_names)
               df[!, Symbol(feature_name)] = [feature_vector[i] for feature_vector in features_v]
           end

           return df
       end
# Out:
# create_circuit_dataframe_direct (generic function with 1 method)

# %% [raw]
# df_circuits = create_circuit_dataframe_direct(nom_v, features_v,feature_names)

# %%
 7×19 DataFrame
 Row │ circuit_name             max_cost  log2_sum_flops_val  topq_mean  avg_cost  std_cost  n_steps  frac_tiny  max_out_rank  avg_out_rank  costw_out_ra ⋯
     │ Any                      Float64   Float64             Float64    Float64   Float64   Float64  Float64    Float64       Float64       Float64      ⋯
─────┼─────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
   1 │ QFT_5_pla_fc                  8.0             10.8502        8.0   4.30952   1.65997     42.0  0.047619            6.0       3.07143         4.912 ⋯
   2 │ QFT_5_pla_gn                  8.0             11.0084        8.0   4.52381   1.64151     42.0  0.0238095           6.0       3.28571         5.034
   3 │ QFT_5_pla_jdrasil             8.0             10.6036        8.0   4.33333   1.44267     42.0  0.0238095           6.0       3.09524         4.547
   4 │ QFT_5_pla_mf                  8.0             10.6036        8.0   4.33333   1.44267     42.0  0.0238095           6.0       3.09524         4.547
   5 │ QFT_5_pla_minfill_mrs         8.0             10.7211        8.0   4.30952   1.55372     42.0  0.047619            6.0       3.07143         4.637 ⋯
   6 │ QFT_5_pla_minfillbg_mrs       8.0             10.545         8.0   4.21429   1.50666     42.0  0.047619            6.0       2.97619         4.527
   7 │ QFT_5_pla_tamaki              7.0             10.236         7.0   4.16667   1.37781     42.0  0.0238095           5.0       2.92857         3.963
                                                                                                                                          9 columns omitted

# %% [markdown]
# Now we can save this information in a file as shown in ``Features.xlsx``

# %% [markdown]
# ---
# ### Summary
# This notebook demonstrated how you can reproduce the file of features ``Features.xls`` from files where you have  circuit contraction plans.
#
#
# Thank you for exploring tensor network construction with us!
